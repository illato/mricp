# %% [markdown]
# ---

# %% [markdown]
# # Graphical Abstract

# %% [markdown]
# ---

# %%
from IPython.display import SVG

SVG("""
<svg viewBox="0 0 1328 531" xmlns="http://www.w3.org/2000/svg">
  <!-- Background -->
  <rect width="1328" height="531" fill="#f8f9fa"/>
  
  <!-- Title -->
  <text x="664" y="45" font-family="Arial, sans-serif" font-size="30" font-weight="bold" text-anchor="middle" fill="#2c3e50">
    Reliable AI Uncertainty for Minority Disease Class Diagnosis
  </text>
  
  <!-- Three main panels -->
  
  <!-- Panel 1: Problem - Marginal CP Failure -->
  <g transform="translate(30, 90)">
    <rect x="0" y="0" width="400" height="380" fill="#ffffff" stroke="#dee2e6" stroke-width="2" rx="8"/>
    
    <!-- Header with gradient -->
    <defs>
      <linearGradient id="redGradient" x1="0%" y1="0%" x2="0%" y2="100%">
        <stop offset="0%" style="stop-color:#e74c3c;stop-opacity:1" />
        <stop offset="100%" style="stop-color:#c0392b;stop-opacity:1" />
      </linearGradient>
    </defs>
    <rect x="0" y="0" width="400" height="60" fill="url(#redGradient)" rx="8"/>
    <text x="200" y="40" font-family="Arial, sans-serif" font-size="24" font-weight="bold" text-anchor="middle" fill="white">
      PROBLEM: Standard CP Fails
    </text>
    
    <!-- Brain MRI icon -->
    <g transform="translate(200, 160)">
      <ellipse cx="0" cy="0" rx="48" ry="52" fill="#f0f0f0" stroke="#666666" stroke-width="2"/>
      <path d="M -30,-20 Q -20,-30 -10,-20 T 10,-20 Q 20,-30 30,-20" 
            fill="none" stroke="#666666" stroke-width="1.5"/>
      <path d="M -25,0 Q -15,-8 -5,0 T 15,0 Q 20,-8 25,0" 
            fill="none" stroke="#666666" stroke-width="1.5"/>
      <path d="M -20,20 Q -10,12 0,20 T 20,20" 
            fill="none" stroke="#666666" stroke-width="1.5"/>
      <circle cx="-15" cy="-5" r="3" fill="#999999"/>
      <circle cx="15" cy="-5" r="3" fill="#999999"/>
    </g>
    
    <!-- Coverage bars with better spacing -->
    <text x="30" y="250" font-family="Arial, sans-serif" font-size="20" fill="#495057">Coverage at 1.5T:</text>
    
    <!-- Healthy controls bar -->
    <text x="30" y="285" font-family="Arial, sans-serif" font-size="18" fill="#495057">Healthy:</text>
    <rect x="120" y="268" width="225" height="24" fill="#D4E6F1" stroke="#3498db" stroke-width="2"/>
    <text x="355" y="284" font-family="Arial, sans-serif" font-size="18" fill="#2874a6">95%</text>
    
    <!-- MS patients bar -->
    <text x="30" y="320" font-family="Arial, sans-serif" font-size="18" fill="#495057">MS:</text>
    <rect x="120" y="303" width="38" height="24" fill="#FADBD8" stroke="#e74c3c" stroke-width="2"/>
    <text x="355" y="319" font-family="Arial, sans-serif" font-size="18" fill="#c0392b">17%</text>
    
    <!-- Failure indicator -->
    <text x="200" y="365" font-family="Arial, sans-serif" font-size="20" font-weight="bold" text-anchor="middle" fill="#c0392b">
      100% Severe Undercoverage
    </text>
  </g>
  
  <!-- Panel 2: Solution - Class-Conditional CP -->
  <g transform="translate(464, 90)">
    <rect x="0" y="0" width="400" height="380" fill="#ffffff" stroke="#dee2e6" stroke-width="2" rx="8"/>
    
    <!-- Header with gradient -->
    <defs>
      <linearGradient id="greenGradient" x1="0%" y1="0%" x2="0%" y2="100%">
        <stop offset="0%" style="stop-color:#27ae60;stop-opacity:1" />
        <stop offset="100%" style="stop-color:#229954;stop-opacity:1" />
      </linearGradient>
    </defs>
    <rect x="0" y="0" width="400" height="60" fill="url(#greenGradient)" rx="8"/>
    <text x="200" y="40" font-family="Arial, sans-serif" font-size="24" font-weight="bold" text-anchor="middle" fill="white">
      SOLUTION: Class-Conditional
    </text>
    
    <!-- Two brain icons for class-specific calibration -->
    <g transform="translate(120, 160)">
      <ellipse cx="0" cy="0" rx="42" ry="46" fill="#E8F6F3" stroke="#3498db" stroke-width="2"/>
      <path d="M -25,-15 Q -18,-22 -10,-15 T 8,-15 Q 15,-22 25,-15" 
            fill="none" stroke="#3498db" stroke-width="1.5"/>
      <path d="M -20,0 Q -12,-6 -4,0 T 12,0 Q 16,-6 20,0" 
            fill="none" stroke="#3498db" stroke-width="1.5"/>
      <text x="0" y="30" font-family="Arial, sans-serif" font-size="16" text-anchor="middle" fill="#2874a6">Healthy</text>
    </g>
    
    <g transform="translate(280, 160)">
      <ellipse cx="0" cy="0" rx="42" ry="46" fill="#FEF5E7" stroke="#f39c12" stroke-width="2"/>
      <path d="M -25,-15 Q -18,-22 -10,-15 T 8,-15 Q 15,-22 25,-15" 
            fill="none" stroke="#f39c12" stroke-width="1.5"/>
      <path d="M -20,0 Q -12,-6 -4,0 T 12,0 Q 16,-6 20,0" 
            fill="none" stroke="#f39c12" stroke-width="1.5"/>
      <circle cx="-10" cy="-5" r="2" fill="#f39c12"/>
      <circle cx="8" cy="-8" r="2" fill="#f39c12"/>
      <circle cx="5" cy="8" r="2" fill="#f39c12"/>
      <text x="0" y="30" font-family="Arial, sans-serif" font-size="16" text-anchor="middle" fill="#d68910">MS</text>
    </g>
    
    <!-- Improved coverage bars -->
    <text x="30" y="250" font-family="Arial, sans-serif" font-size="20" fill="#495057">Improved Coverage:</text>
    
    <!-- Healthy controls bar -->
    <text x="30" y="285" font-family="Arial, sans-serif" font-size="18" fill="#495057">Healthy:</text>
    <rect x="120" y="268" width="200" height="24" fill="#D4E6F1" stroke="#3498db" stroke-width="2"/>
    <text x="330" y="284" font-family="Arial, sans-serif" font-size="18" fill="#2874a6">89%</text>
    
    <!-- MS patients bar -->
    <text x="30" y="320" font-family="Arial, sans-serif" font-size="18" fill="#495057">MS:</text>
    <rect x="120" y="303" width="175" height="24" fill="#FEF5E7" stroke="#f39c12" stroke-width="2"/>
    <text x="330" y="319" font-family="Arial, sans-serif" font-size="18" fill="#d68910">78%</text>
    
    <!-- Success indicator -->
    <text x="200" y="365" font-family="Arial, sans-serif" font-size="20" font-weight="bold" text-anchor="middle" fill="#229954">
      Equitable Coverage
    </text>
  </g>
  
  <!-- Panel 3: Robustness -->
  <g transform="translate(898, 90)">
    <rect x="0" y="0" width="400" height="380" fill="#ffffff" stroke="#dee2e6" stroke-width="2" rx="8"/>
    
    <!-- Header with gradient -->
    <defs>
      <linearGradient id="blueGradient" x1="0%" y1="0%" x2="0%" y2="100%">
        <stop offset="0%" style="stop-color:#2980b9;stop-opacity:1" />
        <stop offset="100%" style="stop-color:#21618c;stop-opacity:1" />
      </linearGradient>
    </defs>
    <rect x="0" y="0" width="400" height="60" fill="url(#blueGradient)" rx="8"/>
    <text x="200" y="40" font-family="Arial, sans-serif" font-size="24" font-weight="bold" text-anchor="middle" fill="white">
      ROBUST to Distribution Shift
    </text>
    
    <!-- Scanner icons and arrow -->
    <g transform="translate(50, 85)">
      <!-- 3T Scanner icon -->
      <rect x="0" y="0" width="60" height="40" fill="#EBF5FB" stroke="#3498db" stroke-width="2" rx="4"/>
      <rect x="10" y="8" width="40" height="24" fill="#ffffff" stroke="#3498db" stroke-width="1"/>
      <text x="30" y="60" font-family="Arial, sans-serif" font-size="16" font-weight="bold" text-anchor="middle" fill="#2874a6">3T</text>
      
      <!-- Arrow -->
      <path d="M 75 20 L 165 20" stroke="#666666" stroke-width="3" marker-end="url(#arrowhead2)"/>
      <text x="110" y="10" font-family="Arial, sans-serif" font-size="14" text-anchor="middle" fill="#666666">deploy</text>
      
      <!-- 1.5T Scanner icon with blur indicator -->
      <rect x="180" y="0" width="60" height="40" fill="#FEF5E7" stroke="#f39c12" stroke-width="2" rx="4"/>
      <rect x="190" y="8" width="40" height="24" fill="#ffffff" stroke="#f39c12" stroke-width="1"/>
      <g transform="translate(210, 20)">
        <circle cx="0" cy="0" r="2" fill="#f39c12" opacity="0.3"/>
        <circle cx="0" cy="0" r="4" fill="#f39c12" opacity="0.2"/>
        <circle cx="0" cy="0" r="6" fill="#f39c12" opacity="0.1"/>
      </g>
      <text x="210" y="60" font-family="Arial, sans-serif" font-size="16" font-weight="bold" text-anchor="middle" fill="#d68910">1.5T</text>
      
      <!-- Blur indicator -->
      <text x="250" y="25" font-family="Arial, sans-serif" font-size="14" fill="#666666">+ blur</text>
    </g>
    
    <!-- Graph showing maintained coverage -->
    <g transform="translate(40, 160)">
      <!-- Axes -->
      <line x1="0" y1="120" x2="320" y2="120" stroke="#666666" stroke-width="2"/>
      <line x1="0" y1="0" x2="0" y2="120" stroke="#666666" stroke-width="2"/>
      
      <!-- Y-axis label -->
      <text x="-30" y="70" font-family="Arial, sans-serif" font-size="14" fill="#666666" transform="rotate(-90, -30, 60)">Coverage</text>
      
      <!-- Target line at 90% -->
      <line x1="0" y1="12" x2="320" y2="12" stroke="#e74c3c" stroke-width="2" stroke-dasharray="6,4"/>
      <text x="325" y="17" font-family="Arial, sans-serif" font-size="16" fill="#e74c3c">90%</text>
      
      <!-- Coverage maintained line -->
      <polyline points="30,15 80,15 130,13 180,13 230,15 280,13" 
                fill="none" stroke="#2980b9" stroke-width="4"/>
      
      <!-- Points -->
      <circle cx="30" cy="15" r="5" fill="#2980b9"/>
      <circle cx="80" cy="15" r="5" fill="#2980b9"/>
      <circle cx="130" cy="13" r="5" fill="#2980b9"/>
      <circle cx="180" cy="13" r="5" fill="#2980b9"/>
      <circle cx="230" cy="15" r="5" fill="#2980b9"/>
      <circle cx="280" cy="13" r="5" fill="#2980b9"/>
      
      <!-- X-axis labels with arrow -->
      <text x="-10" y="140" font-family="Arial, sans-serif" font-size="16" fill="#666666">Base</text>
      <text x="120" y="140" font-family="Arial, sans-serif" font-size="16" fill="#666666">Blur ++</text>
      <text x="260" y="140" font-family="Arial, sans-serif" font-size="16" fill="#666666">Max</text>
    </g>
    
    <!-- Key message -->
    <text x="200" y="340" font-family="Arial, sans-serif" font-size="18" text-anchor="middle" fill="#495057">
      Coverage: 89.6% ± 3.5%
    </text>
    <text x="200" y="365" font-family="Arial, sans-serif" font-size="18" text-anchor="middle" fill="#495057">
      Set size: +80% (adaptive)
    </text>
  </g>
  
  <!-- Arrow marker definition -->
  <defs>
    <marker id="arrowhead2" markerWidth="10" markerHeight="7" refX="9" refY="3.5" orient="auto">
      <polygon points="0 0, 10 3.5, 0 7" fill="#666666"/>
    </marker>
  </defs>
  
  <!-- Bottom banner with message -->
  <rect x="0" y="485" width="1328" height="46" fill="#ecf0f1"/>
  <text x="664" y="513" font-family="Arial, sans-serif" font-size="20" font-style="italic" text-anchor="middle" fill="#34495e">
    Class-conditional conformal prediction enables safe AI deployment for less-prevalent disease diagnosis
  </text>
</svg>
""")

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---
